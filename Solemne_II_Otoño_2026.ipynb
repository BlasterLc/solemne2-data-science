# %% [markdown]
# <div style="text-align: center;"><h1></h1></div>
#
# <h1><center><strong>Solemne II</strong></center></h1>
# <center><strong>Taller de Software para Data Science - Otoño 2026</strong></center>
# <center><strong>Profesor: Ángel Jiménez M.</strong></center>
#
# <center><em>Fecha de Entrega: Hasta Junio 10 de 2026, 23:59:59 </em></center>

# %% [markdown]
# ### Disclaimer
#
# - **No borren ningún contenido de este enunciado**.
# - Respondan en las celdas destinadas para ello, único espacio del enunciado que puede intervenir.
# - Pueden agregar celdas adicionales si lo requieren.
# - Sigan estrictamente las indicaciones.

# %% [markdown]
# ### Equipo
#
# - Nombre/Rut integrante 1:
# - Nombre/Rut integrante 2:
# - Nombre/Rut integrante 3:
# - Nombre/Rut integrante 4:
# - Nombre/Rut integrante 5:
#
# ### Datos administrativos
#
# - **Modalidad:** trabajo grupal de 5 estudiantes.
# - **Fecha de entrega:** miércoles 10 de junio de 2026, 23:59:59 hrs., por Blackboard.
# - **Defensa aleatoria:**  viernes 12 de junio de 2026, durante la clase online.
# - **Formato de entrega:** archivo `<Solemne II_Rut integrante 1>.ipynb` ejecutable en Google Colab, subido a Blackboard. **No se aceptará solo el link al notebook.**
# - **Video:** link de YouTube creado por el grupo, incluido dentro del notebook y entregado en Blackboard. **20 mins. <= Tiempo_video <=30 mins.**
# - **Dataset:** archivo .csv, .xls, .json, etc., subido a Blackboard.
#
#
# *Nota: Si no desea entregar su Rut, ponga su número de estudiante, por favor.*

# %% [markdown]
# ## 1. Temas que evalúa el Solemne II (extraído de los notebooks de las clases)
#
# Este solemne evalúa de manera integrada los contenidos trabajados en las últimas semanas:
#
# 1. Uso de notebooks en Google Colab, Markdown y celdas de código..
# 2. Tipos de datos básicos de Python: números, strings, booleanos, listas, tuplas, conjuntos y diccionarios.
# 3. Control de flujo, iteraciones, comprensión de estructuras mutables e inmutables.
# 4. Definición de funciones, parámetros, valores por defecto, retorno múltiple, `*args`, `**kwargs`, scope local/global y buenas prácticas de modularización.
# 5. Pruebas simples con `assert`, sin uso obligatorio de `unittest`.
# 6. Programación funcional con `map()`, `filter()`, `reduce()` y funciones `lambda`.
# 7. Uso de NumPy para arreglos, operaciones vectorizadas, máscaras y cálculos agregados.
# 8. Uso de Pandas para carga, inspección, transformación, filtrado, agrupación y resumen de datos.
# 9. Visualización y análisis exploratorio de datos: perfilamiento univariado, multivariado, temporal, correlaciones, tablas de contingencia y datos faltantes.
# 10. Interpretación crítica de resultados y construcción de una recomendación basada en evidencia.

# %% [markdown]
# ## 2. Objetivo general
#
# El objetivo de este solemne es que cada grupo construya un **notebook reproducible** para estudiar un caso basado en un dataset real mediante Python y librerías de ciencia de datos.
#
# El solemne no consiste en descargar un dataset y graficarlo sin dirección. Cada grupo debe actuar como un pequeño equipo de análisis contratado para responder una pregunta concreta usando datos reales. El notebook debe contar una historia: desde la búsqueda y evaluación del dataset, hasta la construcción de evidencia, análisis exploratorio, detección de problemas de calidad de datos y formulación de una recomendación final.
#
# ## Objetivos específicos
#
# - Seleccionar críticamente un dataset público o semiabierto, justificando por qué sirve para responder una pregunta analítica.
# - Construir código modular, legible y probado mediante funciones y `assert`.
# - Usar estructuras de datos de Python para organizar metadatos, reglas de validación y resultados intermedios.
# - Aplicar programación funcional para resolver una parte concreta del procesamiento de datos.
# - Usar NumPy y Pandas para transformar, resumir y auditar datos reales.
# - Realizar análisis exploratorio univariado, multivariado y de datos faltantes.
# - Comunicar hallazgos con visualizaciones, texto técnico y conclusiones defendibles.

# %% [markdown]
# ## 3. Contexto del caso
#
# Una organización necesita decidir si un conjunto de datos real puede transformarse en insumo para una decisión importante. Algunos ejemplos posibles:
#
# - Una municipalidad quiere entender patrones de accidentes, movilidad, ruido, reclamos ciudadanos o uso de servicios.
# - Una empresa de retail quiere caracterizar ventas, productos, clientes o sucursales.
# - Un hospital o centro de salud quiere explorar tiempos de atención, demanda o disponibilidad de recursos.
# - Una institución educacional quiere estudiar asistencia, rendimiento, matrícula o abandono.
# - Una organización ambiental quiere monitorear contaminación, temperatura, incendios, precipitaciones o consumo energético.
# - Etc.
#
# El grupo debe elegir **un fenómeno**, buscar un dataset adecuado y construir un análisis completo. La pregunta central debe tener esta forma:
#
# > **¿Qué patrones, problemas de datos y relaciones relevantes se observan en [fenómeno] y qué decisión(es) preliminar(es) se puede(n) recomendar a partir del análisis exploratorio?**
#
# Cada sección del notebook debe avanzar como una investigación conectada. No se aceptarán respuestas que parezcan ejercicios independientes pegados sin hilo conductor.

# %% [markdown]
# ## 4. Requisitos mínimos del dataset
#
# Cada grupo debe buscar y seleccionar su propio dataset. El dataset puede provenir de portales públicos, repositorios institucionales, APIs simples, archivos CSV abiertos, datos gubernamentales, Kaggle u otras fuentes verificables. Debe cumplir al menos con lo siguiente:
#
# ### Requisitos obligatorios
#
# 1. Tener **al menos 800 filas** después de una limpieza inicial razonable. No hay máximo para las filas, aunque probablemente quede sin máquina si escoge uno demasiado grande.
# 2. Tener **al menos 10 columnas**.
# 3. Incluir al menos:
#    - 4 variables numéricas.
#    - 2 variables categóricas.
#    - 1 variable temporal, geográfica u ordinal que permita segmentar el análisis.
# 4. Tener una fuente identificable: URL, institución, fecha de descarga y breve descripción.
# 5. Permitir formular una pregunta propia del grupo para el análisis.
# 6. No haber sido usado como dataset en las clases.
# 7. No ser un dataset excesivamente típico de tutoriales introductorios, por ejemplo: Titanic, Iris, Wine Quality, Palmer Penguins, MNIST, House Prices de Kaggle u Online Retail.
# 8. Debe poder cargarse y ejecutarse en Google Colab sin depender de rutas locales del computador de un integrante.
#
# ### Si el dataset no tiene datos faltantes
#
# Si el dataset seleccionado no contiene datos faltantes reales, el grupo deberá crear una copia llamada `df_stress_missing`, donde introducirá datos faltantes de manera controlada y reproducible en al menos dos columnas. Esta copia se usará solo para la subsección de análisis de datos faltantes, manteniendo intacto el dataset original para el resto del análisis. Esta copia también debe subirla a Blackboard en su entrega.
#
# ### Evidencia de búsqueda de datasets
#
# Antes de elegir el dataset final, el grupo debe comparar **tres datasets candidatos** usando una tabla con:
#
# - Nombre del dataset.
# - Fuente.
# - Cantidad de filas y columnas.
# - Variables principales.
# - Ventajas.
# - Limitaciones.
# - Razón de selección o descarte.

# %% [markdown]
# ## 5. Reglas anti-copia y anti-resolución automática por modelos grandes de lenguaje
#
# Este solemne está diseñado para que no pueda resolverse correctamente solo copiando una respuesta generada por GPT, Gemini, Claude u otro modelo grande de lenguaje. Para ello, el grupo debe incluir evidencia verificable de su propio proceso.
#
# ### Requisitos obligatorios de autenticidad
#
# 1. El dataset debe ser elegido por el grupo y documentado con fuente, fecha de descarga y huella reproducible.
# 2. El notebook debe incluir una **bitácora de decisiones** con al menos 6 decisiones tomadas por el grupo durante el análisis. Detalles más adelante.
# 3. Cada función importante debe tener al menos 2 pruebas con `assert` usando casos pequeños creados por el grupo.
# 4. Cada gráfico debe estar acompañado de una interpretación propia, referida a columnas y valores específicos del dataset.
# 5. Deben existir comentarios explicativos en las celdas de código más relevantes. El código, en general, debe venir comentado.
# 6. El video debe explicar paso a paso el código, especialmente las líneas que implementan funciones, transformaciones y gráficos.
# 7. Todos los integrantes deben conocer el notebook completo.
#
# ### Defensa oral aleatoria
#
# En la clase del **viernes 12 de junio**, de cada grupo se escogerá un/a integrante al azar. Esa persona deberá, con cámara encendida y notebook de Colab desplegado en la clase online, explicar el código fuente y responder preguntas sobre decisiones de implementación e interpretación.
#
# Por lo tanto, **todos/as los/las integrantes deben llegar preparados/as y haber estudiado el solemne completo**.

# %% [markdown]
# ## 6. Librerías permitidas y sugeridas
#
# Pueden usar las siguientes librerías, coherentes con lo trabajado en clases:
#
# - `numpy`
# - `pandas`
# - `matplotlib`
# - `seaborn`
# - `plotly`
# - `scipy`
# - `missingno`
# - `functools`
#
# No está prohibido usar otras librerías, pero si incorporan una librería no vista en clases, deben justificar por qué era necesaria y explicar sus funciones principales en el video.

# %%
# Instalaciones opcionales para Google Colab
# Descomenten solo si es necesario.

# !pip install missingno
# !pip install plotly --upgrade

# %%
# Librerías base sugeridas
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from functools import reduce
from scipy import stats

# Opcional, para análisis de datos faltantes
try:
    import missingno as msno
except ImportError:
    msno = None
    print("missingno no está instalado. Si lo necesitan, ejecuten: !pip install missingno")

# %% [markdown]
# # Parte 0 — Descubrimiento del dataset y formulación del problema [1.0 punto]
#
# En esta parte el grupo debe demostrar que buscó, comparó y seleccionó críticamente un dataset.
#
# ## 0.1 Tabla de datasets candidatos [0.4 puntos]
#
# Construyan una tabla con tres datasets candidatos. Debe incluir fuente, dimensiones, variables relevantes, ventajas, limitaciones y decisión final.
#
# ## 0.2 Pregunta analítica [0.3 puntos]
#
# Formulen una pregunta analítica propia que guíe el análisis. Debe ser específica, responderse parcialmente con análisis exploratorio y mencionar variables o dimensiones del dataset.
#
# Ejemplo de forma, no de contenido:
#
# > ¿Cómo varían los reclamos ciudadanos por zona y tipo de servicio, y qué patrones temporales sugieren prioridades de gestión?
#
# ## 0.3 Criterios de éxito del análisis [0.3 puntos]
#
# Definan tres criterios que permitirán evaluar si el análisis fue útil. Por ejemplo: encontrar segmentos relevantes, detectar problemas de calidad de datos, identificar variables asociadas o proponer una recomendación operacional.

# %% [markdown]
# **Respuesta del grupo:**

# %%
# Completen esta tabla con los tres datasets candidatos.
datasets_candidatos = pd.DataFrame([
    {
        "nombre": "",
        "fuente_url": "",
        "filas_estimadas": None,
        "columnas_estimadas": None,
        "variables_relevantes": "",
        "ventajas": "",
        "limitaciones": "",
        "decision": ""
    },
    {
        "nombre": "",
        "fuente_url": "",
        "filas_estimadas": None,
        "columnas_estimadas": None,
        "variables_relevantes": "",
        "ventajas": "",
        "limitaciones": "",
        "decision": ""
    },
    {
        "nombre": "",
        "fuente_url": "",
        "filas_estimadas": None,
        "columnas_estimadas": None,
        "variables_relevantes": "",
        "ventajas": "",
        "limitaciones": "",
        "decision": ""
    }
])

datasets_candidatos

# %%
# Escriban aquí la pregunta analítica del grupo.
pregunta_analitica = ""

# Definan tres criterios de éxito.
criterios_exito = [
    "",
    "",
    ""
]

print("Pregunta analítica:")
print(pregunta_analitica)

print("\nCriterios de éxito:")
for i, criterio in enumerate(criterios_exito, start=1):
    print(f"{i}. {criterio}")

# %% [markdown]
# # Parte 1 — Carga reproducible y huella del dataset [0.8 puntos]
#
# El notebook debe ser ejecutable en Google Colab. En esta parte deben cargar el dataset seleccionado y dejar evidencia de reproducibilidad.
#
# ## Requisitos
#
# 1. Cargar el dataset desde una URL pública, desde un archivo subido a Colab o desde Google Drive.
# 2. Mostrar las primeras filas con `head()`.
# 3. Mostrar dimensiones con `shape`.
# 4. Mostrar tipos de datos con `info()` o una tabla equivalente.
# 5. Investiguen por su cuenta como calcular una huella del archivo o del DataFrame usando `hashlib`, `pd.util.hash_pandas_object()` u otro método reproducible.
# 6. Registrar fecha de descarga, URL/fuente y breve descripción.

# %% [markdown]
# **Respuesta del grupo:**

# %%
# Completen estos metadatos.
dataset_info = {
    "nombre_dataset": "",
    "fuente_url": "",
    "institucion_fuente": "",
    "fecha_descarga": "",
    "descripcion_breve": "",
    "licencia_o_condiciones_uso": ""
}

dataset_info

# %%
# Carguen aquí el dataset seleccionado.
# Ejemplos posibles:
# df = pd.read_csv("URL_O_RUTA_DEL_ARCHIVO")
# df = pd.read_excel("URL_O_RUTA_DEL_ARCHIVO")
# df = pd.read_json("URL_O_RUTA_DEL_ARCHIVO")

df = None  # Reemplacen esta línea por la carga real.

# Verificación mínima esperada:
# display(df.head())
# print(df.shape)
# df.info()

# %%
# Calculen una huella reproducible del dataset cargado.
# Esta celda es una guía: pueden modificarla si usan otro enfoque.

def calcular_fingerprint_dataframe(dataframe: pd.DataFrame) -> str:
    """
    Retorna una huella hash reproducible del contenido de un DataFrame.
    Debe ser usada para documentar que el grupo trabajó con una versión concreta de los datos.
    """
    # TODO: implementar
    raise NotImplementedError("Implementen la función calcular_fingerprint_dataframe")

# Ejemplo esperado:
# fingerprint = calcular_fingerprint_dataframe(df)
# print(fingerprint)

# %% [markdown]
# # Parte 2 — Diccionario de datos y estructuras básicas de Python [1.0 punto]
#
# Construyan un diccionario de datos usando estructuras nativas de Python. Esta parte evalúa tipos de datos, listas, diccionarios, strings, operaciones básicas, control de flujo y documentación.
#
# ## Requisitos
#
# 1. Crear una lista con las columnas seleccionadas para el análisis.
# 2. Crear un diccionario donde cada clave sea el nombre de una columna relevante.
# 3. Para cada variable, registrar:
#    - Tipo conceptual: numérica, categórica, temporal, geográfica, texto, identificador u otro.
#    - Rol en el análisis.
#    - Descripción en lenguaje natural.
#    - Posibles problemas de calidad.
# 4. Crear un resumen en texto usando `f-strings`.
# 5. Explicar qué variables "tienen pinta" de ser centrales para responder la pregunta analítica.

# %% [markdown]
# **Respuesta del grupo:**

# %%
# Completen con las columnas que utilizarán.
columnas_analisis = []

# Construyan manualmente el diccionario de datos.
diccionario_datos = {
    # "nombre_columna": {
    #     "tipo_conceptual": "",
    #     "rol_analitico": "",
    #     "descripcion": "",
    #     "posibles_problemas": []
    # }
}

# Generen un resumen textual usando f-strings.
# Ejemplo:
# resumen = f"El dataset contiene {df.shape[0]} filas y {df.shape[1]} columnas."
# print(resumen)

# %% [markdown]
# # Parte 3 — Funciones, parámetros, mutabilidad y pruebas con `assert` [1.4 puntos]
#
# Diseñen funciones propias para explorar y describir el dataset. Las funciones deben ser reutilizables y deben tener pruebas simples.
#
# ## Requisitos mínimos
#
# Implementen al menos cuatro funciones:
#
# 1. `normalizar_nombre_columna(nombre)`: recibe un string y retorna una versión normalizada del nombre.
# 2. `clasificar_columna(serie)`: recibe una serie de Pandas y retorna una etiqueta conceptual simple: `"numerica"`, `"categorica"`, `"temporal"`, `"texto"` u otra.
# 3. `resumen_columna(dataframe, columna)`: retorna un diccionario con estadísticas relevantes según el tipo de columna.
# 4. `validar_requisitos_dataset(dataframe, columnas_minimas=10, filas_minimas=800, **kwargs)`: retorna `True` o `False` y un mensaje explicativo.
#
# ## Requisitos técnicos
#
# - Al menos una función debe usar un valor por defecto.
# - Al menos una función debe retornar más de un valor.
# - Al menos una función debe recibir `**kwargs`.
# - Deben incluir al menos 8 pruebas con `assert` en total.
# - Deben explicar brevemente un caso en que la mutabilidad de listas o diccionarios podría producir un error en su análisis.

# %% [markdown]
# **Respuesta del grupo:**

# %%
def normalizar_nombre_columna(nombre: str) -> str:
    """
    Normaliza el nombre de una columna.
    Ejemplo de salida esperada: 'Fecha de Compra' -> 'fecha_de_compra'
    """
    # TODO: implementar
    raise NotImplementedError


def clasificar_columna(serie: pd.Series) -> str:
    """
    Clasifica conceptualmente una columna.
    """
    # TODO: implementar
    raise NotImplementedError


def resumen_columna(dataframe: pd.DataFrame, columna: str) -> dict:
    """
    Retorna un resumen descriptivo de una columna.
    """
    # TODO: implementar
    raise NotImplementedError


def validar_requisitos_dataset(dataframe: pd.DataFrame,
                               columnas_minimas: int = 10,
                               filas_minimas: int = 800,
                               **kwargs):
    """
    Valida requisitos mínimos del dataset.
    Debe retornar al menos dos valores: resultado booleano y mensaje.
    """
    # TODO: implementar
    raise NotImplementedError

# %%
# Pruebas con assert.
# Deben agregar al menos 8 pruebas en total.

# Ejemplos de estructura:
# assert normalizar_nombre_columna("Fecha de Compra") == "fecha_de_compra"
# valido, mensaje = validar_requisitos_dataset(df)
# assert isinstance(valido, bool)
# assert isinstance(mensaje, str)

# %% [markdown]
# # Parte 4 — Programación funcional aplicada al dataset [1.2 puntos]
#
# En esta parte deben usar programación funcional. Deben resolver una tarea de limpieza, transformación o resumen usando `map()`, `filter()`, `reduce()` y al menos una función `lambda`.
#
# ## Requisitos
#
# 1. Usar `map()` para transformar una lista de columnas, categorías o textos.
# 2. Usar `filter()` para seleccionar columnas, categorías o registros que cumplan una condición.
# 3. Usar `reduce()` para calcular un resultado agregado.
# 4. Usar al menos una función `lambda`.
# 5. Incluir al menos 3 pruebas con `assert`.
# 6. En esta parte no se permite resolver todo con `for` o `while`, pues generan ineficiencia; la idea es que aprendan a exprimir al máximo las funciones optimizadas que nos entregan las librerías, las cuales vale mencionar, son bastante más eficientes que los iteradores nativos.
#
# ## Ideas posibles
#
# - Normalizar nombres de columnas.
# - Filtrar variables con cierto porcentaje de datos faltantes.
# - Procesar una columna textual o categórica.
# - Calcular un índice agregado de calidad de datos.
# - Construir una lista de variables candidatas para visualización.

# %% [markdown]
# **Respuesta del grupo:**

# %%
# Implementen aquí la sección de programación funcional.
# Deben usar explícitamente map, filter, reduce y lambda.

# Ejemplo de estructura, no solución:
# columnas_normalizadas = list(map(lambda c: normalizar_nombre_columna(c), df.columns))
# columnas_filtradas = list(filter(lambda c: ..., columnas_normalizadas))
# resultado_agregado = reduce(lambda acc, x: ..., columnas_filtradas, ...)

# %% [markdown]
# # Parte 5 — Transformaciones con NumPy y Pandas [1.3 puntos]
#
# Usen NumPy y Pandas para transformar el dataset y construir variables útiles para el análisis.
#
# ## Requisitos
#
# 1. Crear al menos dos nuevas variables derivadas.
# 2. Usar al menos una operación vectorizada con NumPy o Pandas.
# 3. Realizar al menos dos agrupaciones con `groupby()`.
# 4. Usar `value_counts()`, `crosstab()` o una tabla de contingencia equivalente.
# 5. Filtrar el DataFrame usando condiciones múltiples.
# 6. Justificar por qué las variables creadas ayudan a responder la pregunta analítica.

# %% [markdown]
# **Respuesta del grupo:**

# %%
# Implementen aquí las transformaciones principales.
# Deben conservar una copia del dataset original.

# df_original = df.copy()
# df_trabajo = df.copy()

# TODO: crear variables derivadas
# TODO: operaciones vectorizadas
# TODO: groupby
# TODO: tablas de contingencia
# TODO: filtros con condiciones múltiples

# %% [markdown]
# # Parte 6 — Análisis Exploratorio de Dato (EDA): univariado, multivariado y calidad de datos [2.1 puntos]
#
# Esta es la parte central del solemne. Deben realizar un EDA conectado con la pregunta analítica.
#
# ## 6.1 Perfilamiento univariado [0.4 puntos]
#
# - Analizar la distribución de al menos 3 variables numéricas.
# - Analizar la distribución de al menos 2 variables categóricas.
# - Usar gráficos adecuados: histogramas, boxplots, barras u otros.
# - Interpretar cada gráfico.
#
# ## 6.2 Perfilamiento multivariado [0.5 puntos]
#
# - Relacionar al menos 3 variables independientes con una variable central del análisis (la dependiente o las dependientes).
# - Usar scatterplots, violin plots, boxplots, tablas de contingencia, categorías paralelas u otros gráficos adecuados.
# - Interpretar si se observa separación, tendencia, asociación o ausencia de patrón.
#
# ## 6.3 Correlaciones y relaciones entre variables [0.3 puntos]
#
# - Calcular una matriz de correlación para variables numéricas.
# - Identificar las correlaciones más altas, positivas o negativas.
# - Explicar por qué correlación no implica causalidad.
#
# ## 6.4 Datos faltantes [0.4 puntos]
#
# - Medir porcentaje de datos faltantes por columna.
# - Visualizar datos faltantes con una estrategia tabular o gráfica.
# - Si usan `missingno`, interpretar el gráfico.
# - Si crearon `df_stress_missing`, explicar claramente que es una copia de stress test.
#
# ## 6.5 Prueba estadística exploratoria [0.3 puntos]
#
# Investiguen y apliquen al menos una prueba estadística simple, como:
#
# - Test de normalidad de D’Agostino con `stats.normaltest`.
# - Test Kolmogorov-Smirnov con `stats.ks_2samp`.
# - Otra prueba pertinente, si la explican adecuadamente.
#
# Deben formular hipótesis, ejecutar la prueba e interpretar el resultado con una significancia de 5%. Ojo, en esta pregunta deben investigar un poco sobre estas pruebas estadísticas, entenderlas, aplicarlas e interpretarlas.
#
# ## 6.6 Mini conclusión del EDA [0.2 puntos]
#
# Cerrar esta parte con 5 hallazgos accionables, cada uno en una oración autocontenida.

# %% [markdown]
# **Respuesta del grupo:**

# %%
# 6.1 Perfilamiento univariado
# TODO: gráficos e interpretaciones

# %%
# 6.2 Perfilamiento multivariado
# TODO: gráficos e interpretaciones

# %%
# 6.3 Correlaciones
# TODO: matriz de correlación y ranking de correlaciones

# %%
# 6.4 Datos faltantes
# TODO: análisis de missing values

# %%
# 6.5 Prueba estadística exploratoria
# TODO: formular hipótesis, ejecutar prueba e interpretar

# %% [markdown]
# # Parte 7 — Bitácora de decisiones, recomendación final y entrega [1.2 puntos]
#
# ## 7.1 Bitácora de decisiones [0.3 puntos]
#
# Incluyan una tabla con al menos 6 decisiones tomadas durante el trabajo. Cada decisión debe indicar:
#
# - Decisión tomada.
# - Alternativa descartada.
# - Evidencia usada.
# - Consecuencia sobre el análisis.
#
# ## 7.2 Recomendación final [0.4 puntos]
#
# Redacten una recomendación final para la organización ficticia del caso. Deben responder la pregunta analítica, reconocer límites del análisis y proponer una o varias acciones concretas.
#
# ## 7.3 Limitaciones [0.2 puntos]
#
# Identifiquen al menos 3 limitaciones del dataset o del análisis.
#
# ## 7.4 Entregables y defensa [0.3 puntos]
#
# Deben incluir en esta sección:
#
# 1. Link al video de YouTube.
# 2. Declaración de que todos los integrantes revisaron y pueden explicar el código.
# 3. Distribución de responsabilidades del grupo.
# 4. Confirmación de que el archivo `.ipynb` fue probado en Google Colab antes de subirlo a Blackboard.

# %% [markdown]
# **Respuesta del grupo:**

# %%
# Bitácora de decisiones.
bitacora_decisiones = pd.DataFrame([
    {
        "decision": "",
        "alternativa_descartada": "",
        "evidencia_usada": "",
        "consecuencia": ""
    },
    # Agreguen al menos 6 filas.
])

bitacora_decisiones

# %% [markdown]
# ## Recomendación final
#
# Escriban aquí una recomendación breve, clara y basada en evidencia.
#
# Debe tener la siguiente estructura:
#
# 1. **Respuesta a la pregunta analítica:**
# 2. **Tres hallazgos principales:**
# 3. **Acción recomendada:**
# 4. **Riesgos o precauciones:**
# 5. **Qué análisis harían en una segunda etapa:**

# %% [markdown]
# ## Link del video de YouTube
#
# - Link:
# - Integrantes que explican en el video (deben ser dos):
# - Duración:
# - Declaración: confirmamos que todos los integrantes del grupo comprenden el desarrollo completo del notebook y están preparados para la defensa aleatoria del viernes 12 de junio.

# %% [markdown]
# # Rúbrica resumida
#
# | Parte | Criterio | Puntaje |
# |---|---|---:|
# | 0 | Búsqueda, comparación y formulación del problema | 1.0 |
# | 1 | Carga reproducible y huella del dataset | 0.8 |
# | 2 | Diccionario de datos y estructuras básicas de Python | 1.0 |
# | 3 | Funciones, parámetros, mutabilidad y pruebas con `assert` | 1.4 |
# | 4 | Programación funcional aplicada | 1.2 |
# | 5 | Transformaciones con NumPy y Pandas | 1.3 |
# | 6 | EDA univariado, multivariado, correlaciones, missingness y test estadístico | 2.1 |
# | 7 | Bitácora, recomendación, video y preparación para defensa | 1.2 |
# | **Total** |  | **10.0** |
#
# ## Penalizaciones
#
# - Notebook que no ejecuta en Colab por errores de ruta o dependencias no justificadas: hasta -2.0 puntos de la nota final una vez resuelto el problema.
# - No entregar archivo `.ipynb` por Blackboard: no se corrige, nota 1.0.
# - No incluir video o incluir video inaccesible: no se corrige o hasta -2.0 puntos de la nota final una vez resuelto el problema.
# - Gráficos sin interpretación: máximo 50% del puntaje de la subsección correspondiente.
# - Funciones sin pruebas `assert`: máximo 50% del puntaje de la parte 3.
# - Uso evidente de código que el grupo no puede explicar en defensa: hasta -4.0 puntos de la nota final.
# - Dataset que no cumple requisitos mínimosº: hasta -2.0 puntos de la nota final.

# %% [markdown]
# # Checklist final antes de entregar
#
# Antes de subir el archivo a Blackboard, verifiquen:
#
# - [ ] El archivo entregado es un `.ipynb`, no solo un link.
# - [ ] El notebook corre completo en Google Colab desde cero.
# - [ ] El dataset se carga correctamente.
# - [ ] La fuente del dataset está documentada.
# - [ ] El dataset cumple los requisitos mínimos.
# - [ ] Hay tres datasets candidatos comparados.
# - [ ] Hay pregunta analítica y criterios de éxito.
# - [ ] Hay diccionario de datos.
# - [ ] Hay funciones propias con docstrings.
# - [ ] Hay pruebas con `assert`.
# - [ ] Hay uso explícito de `map`, `filter`, `reduce` y `lambda`.
# - [ ] Hay transformaciones con NumPy/Pandas.
# - [ ] Hay EDA univariado y multivariado.
# - [ ] Hay análisis de datos faltantes.
# - [ ] Hay al menos una prueba estadística exploratoria.
# - [ ] Cada gráfico relevante tiene interpretación.
# - [ ] Hay bitácora de decisiones.
# - [ ] Hay recomendación final.
# - [ ] El link de YouTube funciona.
# - [ ] Todos los integrantes pueden explicar el código completo.

# %% [markdown]
# <center><h1>Referencias útiles de documentación</h1></center>
#
# - Python — Built-in Functions: https://docs.python.org/3/library/functions.html
# - Pandas — User Guide: https://pandas.pydata.org/docs/user_guide/index.html
# - NumPy — Documentation: https://numpy.org/doc/
# - Plotly Express: https://plotly.com/python/plotly-express/
# - SciPy — Statistical functions: https://docs.scipy.org/doc/scipy/reference/stats.html
# - Google Colab: https://colab.research.google.com/
